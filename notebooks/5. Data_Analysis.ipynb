# %% [markdown]
# # **Construção do DF**

# %%
import glob
import pandas as pd

data_folder = "../data/full_enem_data.csv"

# Load merged data
df_enem = pd.read_csv(data_folder)
df_enem.head()
# Out:
#   numero_questao                                          enunciado  \
# 0             91  Para realizar o desentupimento de tubulações d...
# 1             92  As redes de alta tensão para transmissão de en...
# 2             93  A esquistossomose (barriga-dʼágua) caracteriza...
# 3             94  Em 1962, um jingle (vinheta musical) criado po...
# 4             95  Glicólise é um processo que ocorre nas células...
#
#                                         alternativas  nu_param_B gabarito  \
# 0        A: Al; B: Co; C: Cu(OH)2; D: Fe(OH)2; E: Pb     1.13773        A
# 1  A: Fazer o aterramento dos arames da cerca.; B...     1.45214        A
# 2  A: impedir a penetração do parasita pela pele....     0.58402        E
# 3  A: Aquecer a casa e os corpos.; B: Evitar a en...     0.41535        C
# 4  A: libera 112 kJ por mol de glicose.; B: liber...     2.21432        A
#
#     ano
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %% [markdown]
# # **Análise Exploratória**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# import scipy.stats as stats

df = df_enem.rename(columns={"nu_param_B": "dificuldade"})
df.head()
# Out:
#   numero_questao                                          enunciado  \
# 0             91  Para realizar o desentupimento de tubulações d...
# 1             92  As redes de alta tensão para transmissão de en...
# 2             93  A esquistossomose (barriga-dʼágua) caracteriza...
# 3             94  Em 1962, um jingle (vinheta musical) criado po...
# 4             95  Glicólise é um processo que ocorre nas células...
#
#                                         alternativas  dificuldade gabarito  \
# 0        A: Al; B: Co; C: Cu(OH)2; D: Fe(OH)2; E: Pb      1.13773        A
# 1  A: Fazer o aterramento dos arames da cerca.; B...      1.45214        A
# 2  A: impedir a penetração do parasita pela pele....      0.58402        E
# 3  A: Aquecer a casa e os corpos.; B: Evitar a en...      0.41535        C
# 4  A: libera 112 kJ por mol de glicose.; B: liber...      2.21432        A
#
#     ano
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %% [markdown]
# ## **Análise da Dificuldade**

# %%
df.describe()
# Out:
#        dificuldade          ano
# count   654.000000   688.000000
# mean      1.401195  2016.018895
# std       0.895559     4.272173
# min      -1.800920  2009.000000
# 25%       0.859322  2012.000000
# 50%       1.424385  2016.000000
# 75%       1.898725  2020.000000
# max       8.961860  2023.000000

# %%
sns.histplot(df['dificuldade'], bins=30, kde=True)
plt.title('Distribuição da Dificuldade')
plt.xlabel('Dificuldade')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
stats.probplot(df['dificuldade'], dist="norm", plot=plt)
plt.title('Q-Q Plot (Dificuldade)')
plt.show()

# %%
stat, p = stats.shapiro(df[df['dificuldade'].notna()]['dificuldade'])
print(f"Estatística de teste: {stat:.4f} | p-valor: {p:.4f}")

if p > 0.05:
    print("Não rejeita H_0: distribuição normal.")
else:
    print("Rejeita H_0: exclui distribuição normal.")
# Out:
# Estatística de teste: 0.9382 | p-valor: 0.0000
# Rejeita H_0: exclui distribuição normal.

# %%
sns.boxplot(x='ano', y='dificuldade', data=df, order=sorted(df["ano"].unique()))
plt.title('Dificuldade por Ano')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## **Análise de Gabarito**

# %%
df['gabarito'].value_counts().plot(kind='bar', title='Distribuição de Alternativas Corretas')
# Out:
# <Axes: title={'center': 'Distribuição de Alternativas Corretas'}, xlabel='gabarito'>

# %% [markdown]
# # **Análise enunciados**

# %%
df['tam_enunciado'] = df['enunciado'].str.len()
sns.histplot(df['tam_enunciado'], bins=30, kde=True)
plt.title('Distribuição do Tamanho dos Enunciados')
# Out:
# Text(0.5, 1.0, 'Distribuição do Tamanho dos Enunciados')

# %%
sns.scatterplot(x='tam_enunciado', y='dificuldade', data=df)
plt.title('Tamanho do Enunciado vs Dificuldade')
# Out:
# Text(0.5, 1.0, 'Tamanho do Enunciado vs Dificuldade')

# %% [markdown]
# # WordCloud (Gabarito e Alternativas)

# %%
from wordcloud import WordCloud

text = ' '.join(df['enunciado'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras dos Enunciados')
plt.show()

# %%
df['alternativas_adap'] = df['alternativas'].dropna().str.replace(r'[A-E]:\s*', '', regex=True)

text = ' '.join(df['alternativas_adap'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras dos Gabaritos')
plt.show()
